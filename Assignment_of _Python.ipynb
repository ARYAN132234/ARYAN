# %% [markdown]
# 1) What are the types of Applications?

# %% [markdown]
# Ans. Application is a type of softwares or programs that can be created using a particualr language.
# Type of Application :
# 1. System Software
# 2. Application Software
# 3. Web Application
# 4. Embedded Systems

# %% [markdown]
# 2) What is programing?

# %% [markdown]
# Ans. Programming Language are those in which humans are communicating and giving instruction to computer.

# %% [markdown]
# 3) What is Python?

# %% [markdown]
# Ans. Python is an interpreted,general purpose , high level programming language with easy syntax and dynamic meaning.

# %%
#4) Write a Python program to check if a number is positive, negative or zero.
a = int(input("enter "))
if (a==0):
  print("zero")
elif (a%2==0):
  print("positive")
elif (a%2==1):
  print("negative")
else:
  print("not valid")
# Out:
# enter 4
# positive

# %%
#5) Write a Python program to get the Factorial number of given numbers.
num = int(input("Enter a natural number: "))
factorial = 1
for i in range(1, num + 1):
        factorial *= i
print("The factorial of", num, "is", factorial)
# Out:
# Enter a natural number: 5
# The factorial of 5 is 120

# %%
6) Write a Python program to get the Fibonacci series of given range.

# %% [markdown]
# 7) How memory is managed in Python?

# %% [markdown]
# Ans. In python,memory manangement is handled automatically by the python interpreter.

# %% [markdown]
# 8) What is the purpose continuing statement in python?

# %% [markdown]
# Ans. The purpose of continuing statement in python is used to skip the remaining code within the current iteration of a loop and immediately proceed to the next iteration.

# %%
#9) Write python program that swap two number with temp variable and without temp variable.
def swap_numbers(a, b):
    a, b = b, a
    return a, b
print("swapping without temp variable: a = {a}, b = {b}")
a=5
b=10
a,b = swap_numbers(a,b)
print("after swap: a =", a,"b =", b)

# %%
#10) Write a Python program to find whether a given number is even or odd, print out an appropriate message to the user.
num = int(input("enter : "))
if (num%2==0):
  print("Even")
elif (num%2==1):
  print("odd")
else:
  print("Not Valid")
# Out:
# enter : 3
# odd

# %%
#11) Write a Python program to test whether a passed letter is a vowel or not.
vowel = input("enter your letter :")
vowels=("a","e","i","o","u")
if vowel in vowels:
  print("vowel")
else:
  print("not vowel")
# Out:
# enter your letter :s
# not vowel

# %%
#12) Write a Python program to sum of three given integers. However, if two values are equal sum will be zero.
a = int(input("enter your number"))
b = int(input("enter your number"))
c = int(input("enter your number"))
if a==b or b==c or c==a:
  print("0")
else:
  print(a+b+c)
# Out:
# enter your number4
# enter your number4
# enter your number8
# 0

# %%
#13) Write a Python program that will return true if the two given integer values are equal or their sum or difference is 5.
ab = int(input("enter : "))
cd = int(input("enter : "))
if ab==cd or ab+cd==5 or ab-cd==5:
  print("true")
else:
  print("false")
# Out:
# enter : 8
# enter : 4
# false

# %%
#14) Write a python program to sum of the first n positive integers.
def sum_of_first_n_positive_integers(n):
    sum = 0
    for i in range(1, n+1):
        sum += i
    return sum
n = int(input("enter a positive integer: "))
result = sum_of_first_n_positive_integers(n)
print("sum of the first", n, "psitive integers is: ", result)

# %%
#15) Write a Python program to calculate the length of a string.
string = input("enter ")
print(len(string))
# Out:
# enter il
# 2

# %%
#16) Write a Python program to count the number of characters (character frequency) in a stringdef character_frequency(string):
    frequency = {}
    for char in string:
        if char in frequency:
            frequency[char] += 1
        else:
            frequency[char] = 1
    return frequency
input_string ="Hello Google"
frequency_dict = character_frequency(input_string)
for char, freq in frequency_dict.items():
  print(f"Character '{char}' occurs {freq} times")

# %% [markdown]
# 17) What are negative indexes and why are they used?

# %% [markdown]
# Ans. Negative Indexes to start index from the backward side and its uses are slicing  and reverse sequencing.

# %%
#18) Write a Python program to count occurrences of a substring in a string.
string=input("enter a string ")
substring=input("enter a substring ")
count=string.count(substring)
print(count)

# %%
#19) Write a Python program to count the occurrences of each word in a given sentence
def count_words(sentence):
    words = sentence.split()
    word_counts = {}
    for word in words:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1
    return word_counts

sentence = input("enter a sentence: ")
word_counts = count_words(sentence)
for word, count in word_counts.items():
  print(f'{word}:{count}')

# %%
#20) Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.
str1=input("enter a string ")
str2=input("enter a string ")
print(str2[:2]+str1[2:]+" "+str1[:2]+str2[2:])

# %%
"""21) Write a Python program to add 'in' at the end of a given string (length should be at least 3). If the given string already ends with 'ing' then
 add 'ly' instead if the string length of the given string is less than 3, leave it unchanged."""

# %%
#22) Write a Python function to reverses a string if its length is a multiple of 4.
string=input("enter a string ")
if len(string)%4==0:
  print(string[::-1])
else:
  print(string)

# %%
"""23) Write a Python program to get a string made of the first 2 and the last 2 chars from a given a string. If the string length is less than 2, return
instead of the empty string."""
string=input("enter a string ")
if len(string)<2:
  print("")
else:
  print(string[:2]+string[-2:])

# %%
#24) Write a Python function to insert a string in the middle of a string.
def insert_string_middle(string, word):
    return string[:len(string)//2] + word + string[len(string)//2:]
print(insert_string_middle("power bi","excel"))

# %% [markdown]
# 25) What is List? How will you reverse a list?

# %% [markdown]
# Ans. A list is a data structure which is mutable or unchangable.With the help of reverse method we can reverse a list.

# %% [markdown]
# 26) How will you remove last object from a list?

# %% [markdown]
# Ans. With the help of pop function we can remove last object of the list.

# %% [markdown]
# 27) Suppose list1 is [2, 33, 222, 14, and 25], what is list1 [-1]?

# %% [markdown]
# Ans. The list1[-1] will be 25.

# %% [markdown]
# 28) Differentiate between append () and extend () methods?

# %% [markdown]
# Ans. Append and extend both are used to add element to a list.The main difference is that append only add one item while extend add more than one item.

# %%
#29) Write a Python function to get the largest number, smallest num and sum of all from a list.
def largest_smallest_sum(numbers):
    largest = max(numbers)
    smallest = min(numbers)
    total = sum(numbers)
    return largest, smallest, total
numbers = [10,15,35,20,45]
largest, smallest, total = largest_smallest_sum(numbers)
print(f"largest: {largest},smallest: {smallest}, sum: {total}")

# %% [markdown]
# 30)How will you compare two lists?

# %% [markdown]
# Ans. Using "==" operator we can comapare two list.

# %%
"""31) Write a Python program to count the number of strings where the string  length is 2 or more and the first and last character are same from a given list
of strings."""
def count_strings(strings):
    count = 0
    for string in strings:
        if len(string) >= 2 and string[0] == string[-1]:
            count += 1
    return count
strings = ["xyz","jay","het","123","dhruv","a"]
count = count_strings(strings)
print(f"number of strings: {count}")

# %%
#32) Write a Python program to remove duplicates from a list.
del list
my_list = [25,35,40,35,55,45]
unique_list = list(set(my_list))  # Now this should work correctly
print(unique_list)

# %%
#33) Write a Python program to check a list is empty or not.
string=input("enter a string ")
if len(string)==0:
  print("empty")
else:
  print("not empty")

# %%
#34) Write a Python function that takes two lists and returns true if they have at least one common member.
def common_member(list1, list2):
    for item in list1:
        if item in list2:
            return True
    return False
list1 = [7,8,9]
list2 = [1,2,3]
result = common_member(list1,list2)
print(result)

# %%
#35) Write a Python program to generate and print a list of first and last 5 elements where the values are square of numbers between 1 and 30.
list1=[]
for i in range(1,31):
  list1.append(i**2)
print(list1[:5])
print(list1[-5:])

# %%
#36) Write a Python function that takes a list and returns a new list with unique elements of the first list.
my_list = [1,2,3,3,3,3,4,5]
unique_list = list(set(my_list))
print(unique_list)

# %%
#37) Write a Python program to convert a list of characters into a string.
my_list = ["g","o","o","g","l","e"]
my_string = "".join(my_list)
print(my_string)

# %%
 #38) Write a Python program to select an item randomly from a list.
 num=[1,2,3,4,5]
import random
print(random.choice(num))

# %%
#39) Write a Python program to find the second smallest number in a list.
a=[10,20,30,40,50]
a.sort()
print(a[1])

# %%
#40) Write a Python program to get unique values from a list
a=[1,2,2,3,4,4,5]
b=set(a)
print(b)

# %%
#41) Write a Python program to check whether a list contains a sub list
def contains_sublist(list1, list2):
    for item in list2:
        if item not in list1:
            return False
    return True
list1 = [4,5]
list2 = [6,7]
print(contains_sublist(list1, list2))

# %%
#42) Write a Python program to split a list into different variables.
my_list = [1,2,3,4,5]
a,b,c,d,e = my_list
print(a,b,c,d,e)

# %%
"""43) What is tuple? Difference between list and tuple.
Ans. A tuple is a collection of element which is immutable.
The difference between tuple ad list is that list is changable while tuple is unchangable.

# %%
#44) Write a Python program to create a tuple with different data types.
tuple = (1, "world", 2.68, True)
print(tuple)

# %%
#45) Write a Python program to unzip a list of tuples into individual lists.
my_list = [(7,8,9),(15,20,30),(40,55,60)]
x,y,z = zip(*my_list)
print(x)
print(y)
print(z)

# %%
#46) Write a Python program to convert a list of tuples into a dictionary.
my_list = [(40, "banana"),(55, "grapes"),(64, "cherry")]
my_dict = dict(my_list)
print(my_dict)

# %%
#47) How will you create a dictionary using tuples in python?
my_dict = [(1, "banana"),(2, "grapes"),(3, "cherry")]
my_dict = dict(my_dict)
print(my_dict)

# %%
#48) Write a Python script to sort (ascending and descending) a dictionary by value.
my_dict = {1:"apple",2:"watermalon",3:"orange"}
sorted_dict_asc = dict(sorted(my_dict.items(), key=lambda item: item[1]))
print(sorted_dict_asc)
sorted_dict_desc = dict(sorted(my_dict.items(), key=lambda item: item[1],reverse=True))
print(sorted_dict_desc)

# %%
#49) Write a Python script to concatenate following dictionaries to create a new one.
my_dict1 = {"name":"jay","age":"30","gender":"male","address":"ahmedabad"}
my_dict2 = {1:2,2:5,3:10,4:15,5:20}
my_dict3 = {6:30,7:45,8:50,9:55,10:60}
new_dict = {}
for d in (my_dict1,my_dict2,my_dict3):
  new_dict.update(d)
print(new_dict)

# %%
#50) Write a Python script to check if a given key already exists in a dictionary.
my_dict = {"x":1, "y":2, "z":3}
key_to_check = "m"
if key_to_check in my_dict:
  print(f"The key '{key_to_check}' exist in the dictionary.")
else:
  print(f"The key '{key_to_check}' does not exist in the dictionary.")

# %%
#51) How Do You Traverse Through a Dictionary Object in Python?
my_dict = {"name":"jay","age":"30","gender":"male","address":"ahmedabad"}
for key,value in my_dict.items():
  print(key,value)

# %%
"""52) How Do You Check the Presence of a Key in A Dictionary?
Ans. With the help of "in" operator we can check presence of a key in a dictionary.

# %%
#53) Write a Python script to print a dictionary where the keys are numbers between 1 and 15.
my_dict = {}
for i in range(1,16):
  my_dict[i]=i**2
print(my_dict)

# %%
#54) Write a Python program to check multiple keys exists in a dictionary
my_dict = {"Roll no":"10","Name":"het","salary":"20000","age":"24"}
keys_to_check = ["Roll no","Name","salary","age"]
if all(key in my_dict for key in keys_to_check):
  print("All keys exist in the dictionary.")
else:
  print("At least one key does not exist in the dictionary.")

# %%
#55) Write a Python script to merge two Python dictionaries
my_dict1 = {"Roll no":"10","Name":"het","salary":"20000","age":"24"}
my_dict2 = {"city":"ahmedabad","country":"india"}
my_dict1.update(my_dict2)
print(my_dict1)

# %%
#56) Write a Python program to map two lists into a dictionary Sample output: Counter ({'a': 400, 'b': 400,’d’: 400, 'c': 300}).
my_list1 = ["a","b","c","d"]
my_list2 = [400,400,400,300]
my_dict = dict(zip(my_list1,my_list2))
print(my_dict)

# %%
#57) Write a Python program to find the highest 3 values in a dictionary
dic = {"a":500,"b":600,"C":400,"d":300,"e":1000}
sorted_items = sorted(dic.items(), key=lambda item: item[1], reverse=True)
print(dic)
print(sorted_items[:3])
# Out:
# {'a': 500, 'b': 600, 'C': 400, 'd': 300, 'e': 1000}
# [('e', 1000), ('b', 600), ('a', 500)]

# %%
"""58) Write a Python program to combine values in python list of dictionaries.
Sample data: [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300}, o {'item': 'item1', 'amount': 750}]
Expected Output:
• Counter ({'item1': 1150, 'item2': 300}) """
item_list = [{"item": "item1", "amount": 400}, {"item": "item2", "amount": 300}, {"item": "item1", "amount": 750}]

result = Counter()

for item in item_list:
    result[item['item']] += item['amount']

print(result)

# %%
#59) Write a Python program to create a dictionary from a string. Note: Track the count of the letters from the string.
string = "hello google"
my_dict = {}
for char in string:
  if char in my_dict:
    my_dict[char]+=1
  else:
    my_dict[char]=1
print(my_dict)

# %%
"""60) Sample string:
 'w3resource' Expected output:
• {'3': 1,’s’: 1, 'r': 2, 'u': 1, 'w': 1, 'c': 1, 'e': 2, 'o': 1} """
def char_frequency(str1):
    dict = {}
    for n in str1:
        keys = dict.keys()
        if n in keys:
            dict[n] += 1
        else:
            dict[n] = 1
    return dict
print(char_frequency('w3resource'))

# %%
#61) Write a Python function to calculate the factorial of a number (a nonnegative integer)
num = int(input("enter a number: "))
factorial = 1
for i in range(1,num+1):
  factorial=factorial*i
print(factorial)

# %%
#62) Write a Python function to check whether a number is in a given range
num= int(input("enter a number: "))
if num in range(1,101):
  print("yes")
else:
  print("no")

# %%
#63) Write a Python function to check whether a number is perfect or not.
def is_perfect_number(n):
    if n <= 1:
        return False
    sum_divisors = 1
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            sum_divisors += i + n // i
    return sum_divisors == n
number= int(input("enter a number: "))
if is_perfect_number(number):
    print(f"{number} is a perfect number.")
else:
    print(f"{number} is not a perfect number.")

# %%
#64) Write a Python function that checks whether a passed string is palindrome or not
def is_palindrome(s):
  s = s.lower().replace(" ", "")
  return s == s[::-1]

enter_string = input("Enter a string: ")
if is_palindrome(enter_string):
    print(f"{enter_string} is a palindrome.")
else:
    print(f"{enter_string} is not a palindrome.")

# %%
"""65) How Many Basic Types of Functions Are Available in Python?
Ans. There are mainly two type of function in python
1.User defined(def,function name,return statemnt)
2.predfined(abs,bin,bool,list,len)

# %%
"""66) How can you pick a random item from a list or tuple?
Ans. With the help of choice() function we can pick a random item from a list or tuples.

# %%
"""67) How can you pick a random item from a range?
Ans. With the help of randrange() function we can pick a random item from a range.

# %%
"""68) How can you get a random number in python?
Ans.We van use random.randint(a,b) to generate any number between a and b.

# %%
"""69) How will you set the starting value in generating random numbers?
Ans. We can use srand to set the starting point of the sequence.

# %%
"""70) How will you randomize the items of a list in place?
Ans. Shuffle Function can be used to randomize the item of a list in place.

# %%
"""71) What is File function in python? What are keywords to create and write file.
Ans. A File function  is a named of location where the file is stored.
Keywords to create or write file:
1. Write('w') mode
2. Append('a') mode
3. Exclusive Creation('x') mode

# %%
#72) Write a Python program to read an entire text file.
file_path = 'your_file.txt'

try:
    with open(file_path, 'r') as file:
        file_content = file.read()
        print(file_content)
except FileNotFoundError:
    print(f"File not found: {file_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File not found: your_file.txt

# %%
#73) Write a Python program to append text to a file and display the text.
file_path = 'my_file.txt'

text_to_append = "This is some text to append."

try:
    with open(file_path, 'a') as file:
        file.write(text_to_append + '\n')

    with open(file_path, 'r') as file:
        file_content = file.read()
        print(file_content)
except FileNotFoundError:
    print(f"File not found: {file_path}")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
#74) Write a Python program to read first n lines of a file.
def read_first_n_lines(file_path, n):
    try:
        with open(file_path, 'r') as file:
            for i in range(n):
                line = file.readline()
                if line:
                    print(line, end='')
                else:
                    break
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
#75) Write a Python program to read last n lines of a file.
from collections import deque

def read_last_n_lines(file_path, n):
    try:
        with open(file_path, 'r') as file:
            lines = deque(file, maxlen=n)
        for line in lines:
            print(line, end='')
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
#76) Write a Python program to read a file line by line and store it into a list
def read_file_to_list(file_path):
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()
        return lines
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return []
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
#77) Write a Python program to read a file line by line store it into a variable.
def read_file_to_variables(file_path):
    try:
        with open(file_path, 'r') as file:
            line1 = file.readline().strip()
            line2 = file.readline().strip()

        return line1, line2
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return None, None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None, None

# %%
#78) Write a python program to find the longest words.

def find_longest_words(text):
    """Finds the longest word(s) in a given text."""
    words = re.findall(r'\b\w+\b', text)  # Find all words using regex
    longest_word_length = max(len(word) for word in words)  # Get the length of the longest word
    longest_words = [word for word in words if len(word) == longest_word_length]  # Find all words with that length
    return longest_words

# %%
#79) Write a Python program to count the number of lines in a text file.
def count_lines(file_path):
    try:
        with open(file_path, 'r') as file:
            line_count = 0
            for _ in file:
                line_count += 1
            return line_count
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return 0
    except Exception as e:
        print(f"An error occurred: {e}")
        return 0

# %%
#80) Write a Python program to count the frequency of words in a file.
import re
from collections import Counter

def word_frequency(file_path):
    try:
        with open(file_path, 'r') as file:
            text = file.read().lower()
            words = re.findall(r'\b\w+\b', text)
            word_counts = Counter(words)
            return word_counts
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return {}
    except Exception as e:
        print(f"An error occurred: {e}")
        return {}

file_path = 'your_file.txt'
word_counts = word_frequency(file_path)

for word, count in word_counts.items():
    print(f"{word}: {count}")

# %%
#81) Write a Python program to write a list to a file.
my_list = ["apple", "banana", "cherry", "date"]

file_path = 'my_file.txt'

try:
    with open(file_path, 'w') as file:
        for item in my_list:
            file.write(item + '\n')
    print(f"List written to '{file_path}' successfully.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
#82) Write a Python program to copy the contents of a file to another file.
import shutil
source_file = "source.txt"
destination_file = "destination.txt"

try:
    shutil.copy2(source_file, destination_file)
    print(f"File '{source_file}' copied to '{destination_file}' successfully.")
except FileNotFoundError:
    print(f"Source file not found: {source_file}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Source file not found: source.txt

# %%
"""83) Explain Exception handling? What is an Error in Python?
Ans. Exception handling handles the errors that occur during the execution of the program.
An error in python is an issue that prevents a program from completing its task.

# %%
"""84) How many except statements can a try-except block have? Name Some built-in exception classes:
Ans. A try-except block in  python can have more than one except statement:
1. At least one except statement
2. Multiple except blocks
3. Catching multiple exceptions

# %%
"""85) When will the else part of try-except-else be executed?
Ans. Else will be exceuted in try-except when there are no exception raised within the try block.

# %%
"""86) Can one block of except statements handle multiple exception?
Ans. Yes,one block of except statements handle multiple exception.

# %%
"""87) When is the finally block executed?
Ans. A fial block executed when the try block exits.

# %%
"""88) What happens when „1‟== 1 is executed?
Ans. Wen 1==1 is executed it will give us true result.

# %%
"""89) How Do You Handle Exceptions with Try/Except/Finally in Python? Explain with coding snippets.
Ans.Exception Handling handles errors that occur during the execution of a program.
Exception handling allows to respond to the error, instead of crashing the running program.
It enables you to catch and manage errors, making your code more robust and user-friendly."""
n = 10
try:
    res = n / 0

except ZeroDivisionError:
    print("Can't be divided by zero!")

# %%
#90) Write python program that user to enter only odd numbers, else will raise an exception.
class EvenNumberError(Exception):
    """Custom exception for even numbers."""
    pass

def get_odd_number():
    while True:
        try:
            num = int(input("Enter an odd number: "))
            if num % 2 == 0:
                raise EvenNumberError("Even number entered!")
            return num
        except ValueError:
            print("Invalid input. Please enter a number.")
        except EvenNumberError as e:
            print(e)
